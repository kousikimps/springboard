# %%
import json
import pandas as pd
from pandas.io.json import json_normalize

# %%
# load as Pandas dataframe
json_data=pd.read_json('world_bank_projects.json')
json_data.head(2)
# Out:
#                                               sector supplementprojectflg  \
# 0  [{'Name': 'Primary education'}, {'Name': 'Seco...                    N
# 1  [{'Name': 'Public administration- Other social...                    N
#
#   projectfinancialtype prodline  \
# 0                  IDA       PE
# 1                OTHER       RE
#
#                                              mjtheme  idacommamt  \
# 0                                [Human development]   130000000
# 1  [Economic management, Social protection and ri...           0
#
#                impagency                                       project_name  \
# 0  MINISTRY OF EDUCATION  Ethiopia General Education Quality Improvement...
# 1    MINISTRY OF FINANCE          TN: DTF Social Protection Reforms Support
#
#   mjthemecode           closingdate  ...  \
# 0        8,11  2018-07-07T00:00:00Z  ...
# 1         1,6                   NaN  ...
#
#                                  majorsector_percent board_approval_month  \
# ...

# %% [markdown]
# # JSON exercise
# Using data in file 'data/world_bank_projects.json' and the techniques demonstrated above,
#
# Find the 10 countries with most projects
#
# Find the top 10 major project themes (using column 'mjtheme_namecode')
#
# In 2. above you will notice that some entries have only the code and the name is missing. Create a dataframe with the missing names filled in.

# %%
json_data[["countryshortname","project_name"]]
# Out:
#                      countryshortname  \
# 0                            Ethiopia
# 1                             Tunisia
# 2                              Tuvalu
# 3                  Yemen, Republic of
# 4                             Lesotho
# ..                                ...
# 495                           Jamaica
# 496  Lao People's Democratic Republic
# 497                            Guinea
# 498                         Indonesia
# 499                             Kenya
#
#                                           project_name
# 0    Ethiopia General Education Quality Improvement...
# 1            TN: DTF Social Protection Reforms Support
# 2    Tuvalu Aviation Investment Project - Additiona...
# 3     Gov't and Civil Society Organization Partnership
# 4    Second Private Sector Competitiveness and Econ...
# ..                                                 ...
# 495  Technological Scale Up for Youth-led Urban Orn...
# 496                Lao Eight Poverty Reduction Support
# ...

# %%
data=json_data.groupby(["countryshortname"]).count()[['project_name']].sort_values(["project_name"],ascending=False).rename({'countryshortname': 'TotalProjectName'}, axis=1)

# %%
#Find the 10 countries with most projects
data[:10]
# Out:
#                     project_name
# countryshortname
# China                         19
# Indonesia                     19
# Vietnam                       17
# India                         16
# Yemen, Republic of            13
# Nepal                         12
# Bangladesh                    12
# Morocco                       12
# Mozambique                    11
# Africa                        11

# %%
# load json as string
json_load=json.load((open('world_bank_projects.json')))

#Find the top 10 major project themes (using column 'mjtheme_namecode')

project_theme = json_normalize (data=json_load,record_path='mjtheme_namecode',meta=['countryshortname','id'])

project_theme.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1499 entries, 0 to 1498
# Data columns (total 4 columns):
# code                1499 non-null object
# name                1499 non-null object
# countryshortname    1499 non-null object
# id                  1499 non-null object
# dtypes: object(4)
# memory usage: 47.0+ KB

# %%
top_10_project_theme=project_theme.groupby(["name"]).count()[["code"]].sort_values(["code"],ascending=False).rename({'name': 'TotalProjects'},axis=1)
top_10_project_theme[:10]
# Out:
#                                               code
# name
# Environment and natural resources management   223
# Rural development                              202
# Human development                              197
# Public sector governance                       184
# Social protection and risk management          158
# Financial and private sector development       130
#                                                122
# Social dev/gender/inclusion                    119
# Trade and integration                           72
# Urban development                               47

# %%
#Create a dataframe with the missing names filled in.
normialized_data_copy=project_theme.copy()

# %%
normialized_data_copy["name"]=normialized_data_copy["name"].apply(lambda x: "Unknown" if x.strip()=='' else x)

# %%
normialized_data_copy.head(10)
# Out:
#   code                                          name    countryshortname  \
# 0    8                             Human development            Ethiopia
# 1   11                                       Unknown            Ethiopia
# 2    1                           Economic management             Tunisia
# 3    6         Social protection and risk management             Tunisia
# 4    5                         Trade and integration              Tuvalu
# 5    2                      Public sector governance              Tuvalu
# 6   11  Environment and natural resources management              Tuvalu
# 7    6         Social protection and risk management              Tuvalu
# 8    7                   Social dev/gender/inclusion  Yemen, Republic of
# 9    7                   Social dev/gender/inclusion  Yemen, Republic of
#
#         id
# 0  P129828
# 1  P129828
# 2  P144674
# 3  P144674
# 4  P145310
# 5  P145310
# 6  P145310
# 7  P145310
# 8  P144665
# 9  P144665

# %%
normialized_data_copy.groupby(["name"]).count()[["code"]].sort_values(["code"],ascending=False).rename({'name': 'TotalProjects'},axis=1)
# Out:
#                                               code
# name
# Environment and natural resources management   223
# Rural development                              202
# Human development                              197
# Public sector governance                       184
# Social protection and risk management          158
# Financial and private sector development       130
# Unknown                                        122
# Social dev/gender/inclusion                    119
# Trade and integration                           72
# Urban development                               47
# Economic management                             33
# Rule of law                                     12
