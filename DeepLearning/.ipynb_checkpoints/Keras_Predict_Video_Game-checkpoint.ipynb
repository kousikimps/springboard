# %%
import pandas as pd
from keras.models import Sequential
from keras.layers import *
from sklearn.preprocessing import MinMaxScaler
from keras.models import load_model
# Out:
# Using TensorFlow backend.

# %%
####### Predict Total Earnings for Video Game ############

# %%
# Load training data set from CSV file
training_data_df = pd.read_csv('sales_data_training.csv')

# %%
training_data_df.head()
# Out:
#    critic_rating  is_action  is_exclusive_to_us  is_portable  is_role_playing  \
# 0            3.5          1                   0            1                0
# 1            4.5          0                   0            0                0
# 2            3.0          0                   0            0                0
# 3            4.5          1                   0            0                0
# 4            4.0          1                   0            1                0
#
#    is_sequel  is_sports  suitable_for_kids  total_earnings  unit_price
# 0          1          0                  0          132717       59.99
# 1          1          1                  0           83407       49.99
# 2          1          1                  0           62423       49.99
# 3          0          0                  1           69889       39.99
# 4          1          0                  1          161382       59.99

# %%
# Load testing data set from CSV file
test_data_df = pd.read_csv('sales_data_test.csv')

# %%
test_data_df.head()
# Out:
#    critic_rating  is_action  is_exclusive_to_us  is_portable  is_role_playing  \
# 0            3.5          1                   1            1                0
# 1            2.5          0                   0            0                1
# 2            3.5          0                   0            0                0
# 3            4.0          1                   1            0                0
# 4            2.0          1                   0            1                0
#
#    is_sequel  is_sports  suitable_for_kids  total_earnings  unit_price
# 0          1          0                  1          247537       59.99
# 1          1          0                  0           73960       59.99
# 2          1          1                  0           82671       59.99
# 3          1          0                  0          137456       39.99
# 4          1          0                  0           89639       59.99

# %%
# Data needs to be scaled to a small range like 0 to 1 for the neural
# network to work well.
scaler = MinMaxScaler(feature_range=(0,1))

# %%
# Scale both the training inputs and outputs
scaled_training = scaler.fit_transform(training_data_df)
scaled_testing = scaler.fit_transform(test_data_df)

# %%
# Print out the adjustment that the scaler applied to the total_earnings column of data
print("Note: total_earnings values were scaled by multiplying by {:.10f} and adding {:.6f}".format(scaler.scale_[8], scaler.min_[8]))
# Out:
# Note: total_earnings values were scaled by multiplying by 0.0000042367 and adding -0.153415

# %%
# Create new pandas DataFrame objects from the scaled data
scaled_training_df = pd.DataFrame(scaled_training, columns=training_data_df.columns.values)
scaled_testing_df = pd.DataFrame(scaled_testing, columns=test_data_df.columns.values)

# %%
# Save scaled data dataframes to new CSV files
scaled_training_df.to_csv("sales_data_training_scaled.csv", index=False)
scaled_testing_df.to_csv("sales_data_test_scaled.csv", index=False)

# %%
training_data_df_scaled = pd.read_csv("sales_data_training_scaled.csv")
training_data_df_scaled.head()
# Out:
#    critic_rating  is_action  is_exclusive_to_us  is_portable  is_role_playing  \
# 0       0.500000        1.0                 0.0          1.0              0.0
# 1       0.833333        0.0                 0.0          0.0              0.0
# 2       0.333333        0.0                 0.0          0.0              0.0
# 3       0.833333        1.0                 0.0          0.0              0.0
# 4       0.666667        1.0                 0.0          1.0              0.0
#
#    is_sequel  is_sports  suitable_for_kids  total_earnings  unit_price
# 0        1.0        0.0                0.0        0.374714         1.0
# 1        1.0        1.0                0.0        0.192425         0.5
# 2        1.0        1.0                0.0        0.114852         0.5
# 3        0.0        0.0                1.0        0.142452         0.0
# 4        1.0        0.0                1.0        0.480682         1.0

# %%
X = training_data_df_scaled.drop('total_earnings', axis=1).values
Y = training_data_df_scaled[['total_earnings']].values

# Define the model
model = Sequential()
model.add(Dense(50, input_dim=9, activation='relu'))
model.add(Dense(100, activation='relu'))
model.add(Dense(50, activation='relu'))
model.add(Dense(1, activation='linear'))
model.compile(loss='mean_squared_error', optimizer='adam')

# Train the model
model.fit(
    X,
    Y,
    epochs=50,
    shuffle=True,
    verbose=2
)
# Out:
# Epoch 1/50
#  - 1s - loss: 0.0346
# Epoch 2/50
#  - 0s - loss: 0.0048
# Epoch 3/50
#  - 0s - loss: 0.0018
# Epoch 4/50
#  - 0s - loss: 8.5914e-04
# Epoch 5/50
#  - 0s - loss: 4.5658e-04
# Epoch 6/50
#  - 0s - loss: 2.6425e-04
# Epoch 7/50
#  - 0s - loss: 1.9665e-04
# Epoch 8/50
#  - 0s - loss: 1.3480e-04
# Epoch 9/50
#  - 0s - loss: 1.0088e-04
# Epoch 10/50
#  - 0s - loss: 8.4523e-05
# Epoch 11/50
#  - 0s - loss: 6.8362e-05
# Epoch 12/50
#  - 0s - loss: 5.8142e-05
# Epoch 13/50
#  - 0s - loss: 5.1911e-05
# Epoch 14/50
#  - 0s - loss: 4.4638e-05
# Epoch 15/50
#  - 0s - loss: 5.0661e-05
# Epoch 16/50
#  - 0s - loss: 4.6242e-05
# Epoch 17/50
#  - 0s - loss: 4.1332e-05
# Epoch 18/50
#  - 0s - loss: 3.3192e-05
# Epoch 19/50
#  - 0s - loss: 3.1578e-05
# Epoch 20/50
#  - 0s - loss: 3.2839e-05
# Epoch 21/50
#  - 0s - loss: 3.9240e-05
# Epoch 22/50
#  - 0s - loss: 3.5365e-05
# Epoch 23/50
#  - 0s - loss: 2.7566e-05
# Epoch 24/50
#  - 0s - loss: 2.7898e-05
# Epoch 25/50
# ...

# %%
# Load the separate test data set
test_data_df_scaled = pd.read_csv("sales_data_test_scaled.csv")

X_test = test_data_df_scaled.drop('total_earnings', axis=1).values
Y_test = test_data_df_scaled[['total_earnings']].values

test_error_rate = model.evaluate(X_test,Y_test,verbose=0)
print("The mean squared error (MSE) for the test data set is: {}".format(test_error_rate))
# Out:
# The mean squared error (MSE) for the test data set is: 0.0013924493780359626

# %%
pedicted_data= model.predict(X_test)

# %%
pedicted_data
# Out:
# array([[ 0.80301076],
#        [ 0.16264383],
#        [ 0.19209723],
#        [ 0.39437357],
#        [ 0.22807366],
#        [ 0.26526263],
#        [ 0.23011546],
#        [ 0.7164314 ],
#        [ 0.42836294],
#        [ 0.39410245],
#        [ 0.23225933],
#        [ 0.3343694 ],
#        [ 0.25039557],
#        [ 0.3447453 ],
#        [ 0.4098072 ],
#        [ 0.2206171 ],
#        [ 0.28036073],
#        [ 0.04970721],
#        [ 0.23225933],
#        [ 0.27120352],
#        [ 0.19852903],
#        [ 0.2788736 ],
#        [ 0.39410245],
#        [ 0.20691583],
#        [ 0.4159467 ],
#        [ 0.28036073],
#        [ 0.40832534],
#        [ 0.18019092],
#        [ 0.14552687],
#        [ 0.2792821 ],
#        [ 0.16264378],
#        [ 0.57729274],
#        [ 0.18613572],
#        [ 0.6026077 ],
#        [ 0.19371545],
#        [ 0.1301994 ],
#        [ 0.34451425],
#        [ 0.1656725 ],
#        [ 0.45761004],
#        [ 0.7310489 ],
#        [ 0.05565917],
# ...

# %%
test_data_df_scaled.head()
# Out:
#    critic_rating  is_action  is_exclusive_to_us  is_portable  is_role_playing  \
# 0       0.500000        1.0                 1.0          1.0              0.0
# 1       0.166667        0.0                 0.0          0.0              1.0
# 2       0.500000        0.0                 0.0          0.0              0.0
# 3       0.666667        1.0                 1.0          0.0              0.0
# 4       0.000000        1.0                 0.0          1.0              0.0
#
#    is_sequel  is_sports  suitable_for_kids  total_earnings  unit_price
# 0        1.0        0.0                1.0        0.895324         1.0
# 1        1.0        0.0                0.0        0.159931         1.0
# 2        1.0        1.0                0.0        0.196837         1.0
# 3        1.0        0.0                0.0        0.428944         0.0
# 4        1.0        0.0                0.0        0.226358         1.0

# %%
# Save the model to disk
model.save("trained_mode.h5")
print("Model Saved to Disk")
# Out:
# Model Saved to Disk

# %%
# Load the data we make to use to make a prediction
X = pd.read_csv("proposed_new_product.csv").values

#Load model from trained data
model = load_model('trained_mode.h5')

# Make a prediction with the neural network
prediction = model.predict(X)

# Grab just the first element of the first prediction (since that's the only have one)
prediction = prediction[0][0]

# Re-scale the data from the 0-to-1 range back to dollars
# These constants are from when the data was originally scaled down to the 0-to-1 range
prediction = prediction + 0.1159
prediction = prediction / 0.0000036968

print("Earnings Prediction for Proposed Product - ${}".format(prediction))
# Out:
# Earnings Prediction for Proposed Product - $264618.1214761228

# %%
X
# Out:
# array([[0.7, 1. , 1. , 1. , 0. , 1. , 0. , 1. , 0.8]])
